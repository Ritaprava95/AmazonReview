# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/amazon/Sample_Submission.csv
# /kaggle/input/amazon/train.csv
# /kaggle/input/amazon/test.csv
# /kaggle/input/glove6b/glove.6B.200d.txt
# /kaggle/input/glove6b/glove.6B.50d.txt
# /kaggle/input/glove6b/glove.6B.300d.txt
# /kaggle/input/glove6b/glove.6B.100d.txt

# %% [markdown]
# Importing all the necessary packages

# %%
import os
import numpy as np
import pandas as pd
import re
import string
from string import digits
import keras.backend as K
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Input, Embedding, SimpleRNN, LSTM, Dropout, Activation, Concatenate
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.optimizers import Adam, SGD, RMSprop
import matplotlib.pyplot as plt

# %% [markdown]
# Importing and preparing data

# %%
train_data = pd.read_csv("/kaggle/input/amazon/train.csv")


train_title_X = train_data.loc[:,'Review Title']
train_title_X = [x.lower() for x in train_title_X]
#train_title_X = [re.sub("'", '', x) for x in train_title_X]
train_text_X = train_data.loc[:,'Review Text']
train_text_X = [x.lower() for x in train_text_X]
#train_text_X = [re.sub("'", '', x) for x in train_text_X]
train_y = train_data['topic']
train_y = pd.get_dummies(train_y)

t = Tokenizer()
t.fit_on_texts(train_title_X)
title_vocab_size = len(t.word_index) + 1
    
encoded_train_title_X = t.texts_to_sequences(train_title_X)
    
word_title_index = t.word_index

t.fit_on_texts(train_text_X)
text_vocab_size = len(t.word_index) + 1

encoded_train_text_X = t.texts_to_sequences(train_text_X)

word_text_index = t.word_index


max_title_length = max([len(x) for x in encoded_train_title_X])
padded_train_title_X = pad_sequences(encoded_train_title_X, maxlen=max_title_length, padding='post')

max_text_length = max([len(x) for x in encoded_train_text_X])
padded_train_text_X = pad_sequences(encoded_train_text_X, maxlen=max_text_length, padding='post')
    
    
embeddings_index = dict()
words = []
f = open('/kaggle/input/glove6b/glove.6B.100d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    words.append(word)
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
    	
f.close()
#print('Loaded %s word vectors.' % len(embeddings_index))
    
embedding_title_matrix = np.zeros((title_vocab_size, 100))
for word, i in word_title_index.items():
   embedding_vector = embeddings_index.get(word)
   if embedding_vector is not None:
       embedding_title_matrix[i] = embedding_vector
       
embedding_text_matrix = np.zeros((text_vocab_size, 100))
for word, i in word_text_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_text_matrix[i] = embedding_vector

# %% [markdown]
# Defining the model

# %%
sentences_title = Input((max_title_length,), dtype='int32')
embeddings_title = Embedding(title_vocab_size, 100, weights=[embedding_title_matrix], input_length=max_title_length, trainable=False)(sentences_title)
X = LSTM(128, return_sequences=False)(embeddings_title)
X = Dropout(0.2)(X)
#X = Activation('softmax')(X)

sentences_text = Input((max_text_length,), dtype='int32')
embeddings_text = Embedding(text_vocab_size, 100, weights=[embedding_text_matrix], input_length=max_text_length, trainable=False)(sentences_text)
X2 = LSTM(128, return_sequences=True)(embeddings_text)
X2 = LSTM(128, return_sequences=False)(X2)
X2 = Dropout(0.2)(X)
X3 = Concatenate()([X,X2])
X3 = Dense(21)(X2)
output = Activation('softmax')(X3)
    
model = Model(inputs=[sentences_title,sentences_text], outputs=output)
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 20)                0
# _________________________________________________________________
# embedding_13 (Embedding)     (None, 20, 100)           258800
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 128)               117248
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 21)                2709
# _________________________________________________________________
# activation_7 (Activation)    (None, 21)                0
# =================================================================
# Total params: 378,757
# Trainable params: 119,957
# Non-trainable params: 258,800
# _________________________________________________________________

# %% [markdown]
# Compiling and training

# %%
epochs=50
lr=.001
decay = lr/epochs
adam = Adam(lr=lr, beta_1=.9, beta_2=.999, decay=decay)
sgd = SGD(lr=.001)
rmsprop = RMSprop(lr=.001)
optimizer = adam

print('Optimizer :'+str(optimizer))
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.fit([padded_train_title_X,padded_train_text_X] , train_y, validation_split=0.3, epochs=epochs, verbose=1, batch_size=32)
plt.figure()
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.legend(['training', 'validation'])
plt.xlabel('epochs')
plt.xlabel('accuracy')
# Out:
# Optimizer :<keras.optimizers.Adam object at 0x7f0b3073c7b8>
# Train on 4171 samples, validate on 1788 samples
# Epoch 1/50
# 4171/4171 [==============================] - 5s 1ms/step - loss: 2.6040 - accuracy: 0.2103 - val_loss: 2.4070 - val_accuracy: 0.2472
# Epoch 2/50
# 4171/4171 [==============================] - 4s 899us/step - loss: 2.3588 - accuracy: 0.2700 - val_loss: 2.2771 - val_accuracy: 0.3082
# Epoch 3/50
# 4171/4171 [==============================] - 4s 855us/step - loss: 2.2641 - accuracy: 0.3225 - val_loss: 2.2081 - val_accuracy: 0.3238
# Epoch 4/50
# 4171/4171 [==============================] - 3s 807us/step - loss: 2.1788 - accuracy: 0.3553 - val_loss: 2.1529 - val_accuracy: 0.3574
# Epoch 5/50
# 4171/4171 [==============================] - 4s 863us/step - loss: 2.1181 - accuracy: 0.3728 - val_loss: 2.1605 - val_accuracy: 0.3596
# Epoch 6/50
# 4171/4171 [==============================] - 3s 813us/step - loss: 2.0668 - accuracy: 0.3963 - val_loss: 2.0963 - val_accuracy: 0.3786
# Epoch 7/50
# 4171/4171 [==============================] - 4s 916us/step - loss: 2.0205 - accuracy: 0.4047 - val_loss: 2.0725 - val_accuracy: 0.3943
# Epoch 8/50
# 4171/4171 [==============================] - 4s 875us/step - loss: 1.9846 - accuracy: 0.4164 - val_loss: 2.0940 - val_accuracy: 0.3915
# Epoch 9/50
# 4171/4171 [==============================] - 3s 806us/step - loss: 1.9512 - accuracy: 0.4301 - val_loss: 2.0510 - val_accuracy: 0.4183
# Epoch 10/50
# 4171/4171 [==============================] - 3s 810us/step - loss: 1.9104 - accuracy: 0.4366 - val_loss: 2.0154 - val_accuracy: 0.4116
# Epoch 11/50
# 4171/4171 [==============================] - 4s 883us/step - loss: 1.8633 - accuracy: 0.4558 - val_loss: 2.0107 - val_accuracy: 0.4234
# Epoch 12/50
# 4171/4171 [==============================] - 3s 808us/step - loss: 1.8288 - accuracy: 0.4601 - val_loss: 2.0154 - val_accuracy: 0.4245
# Epoch 13/50
# 4171/4171 [==============================] - 3s 806us/step - loss: 1.7960 - accuracy: 0.4713 - val_loss: 1.9799 - val_accuracy: 0.4306
# Epoch 14/50
# 4171/4171 [==============================] - 4s 869us/step - loss: 1.7547 - accuracy: 0.4853 - val_loss: 1.9969 - val_accuracy: 0.4340
# Epoch 15/50
# 4171/4171 [==============================] - 3s 813us/step - loss: 1.7314 - accuracy: 0.4968 - val_loss: 1.9831 - val_accuracy: 0.4351
# Epoch 16/50
# 4171/4171 [==============================] - 3s 801us/step - loss: 1.7007 - accuracy: 0.4992 - val_loss: 1.9822 - val_accuracy: 0.4368
# Epoch 17/50
# 4171/4171 [==============================] - 4s 929us/step - loss: 1.6704 - accuracy: 0.5133 - val_loss: 2.0426 - val_accuracy: 0.4312
# Epoch 18/50
# 4171/4171 [==============================] - 4s 852us/step - loss: 1.6415 - accuracy: 0.5205 - val_loss: 1.9937 - val_accuracy: 0.4346
# Epoch 19/50
# 4171/4171 [==============================] - 3s 803us/step - loss: 1.6025 - accuracy: 0.5310 - val_loss: 2.0492 - val_accuracy: 0.4362
# Epoch 20/50
# 4171/4171 [==============================] - 3s 805us/step - loss: 1.5859 - accuracy: 0.5267 - val_loss: 2.0346 - val_accuracy: 0.4374
# Epoch 21/50
# 4171/4171 [==============================] - 4s 864us/step - loss: 1.5412 - accuracy: 0.5392 - val_loss: 2.0526 - val_accuracy: 0.4279
# Epoch 22/50
# 4171/4171 [==============================] - 3s 812us/step - loss: 1.5418 - accuracy: 0.5370 - val_loss: 2.0326 - val_accuracy: 0.4418
# Epoch 23/50
# 4171/4171 [==============================] - 3s 809us/step - loss: 1.4926 - accuracy: 0.5584 - val_loss: 2.0598 - val_accuracy: 0.4340
# Epoch 24/50
# 4171/4171 [==============================] - 4s 867us/step - loss: 1.4703 - accuracy: 0.5579 - val_loss: 2.0625 - val_accuracy: 0.4430
# Epoch 25/50
# 4171/4171 [==============================] - 3s 807us/step - loss: 1.4632 - accuracy: 0.5553 - val_loss: 2.0343 - val_accuracy: 0.4385
# Epoch 26/50
# 4171/4171 [==============================] - 3s 812us/step - loss: 1.4334 - accuracy: 0.5740 - val_loss: 2.0979 - val_accuracy: 0.4329
# Epoch 27/50
# 4171/4171 [==============================] - 4s 856us/step - loss: 1.4099 - accuracy: 0.5682 - val_loss: 2.1204 - val_accuracy: 0.4312
# Epoch 28/50
# 4171/4171 [==============================] - 4s 929us/step - loss: 1.3917 - accuracy: 0.5711 - val_loss: 2.1087 - val_accuracy: 0.4323
# Epoch 29/50
# 4171/4171 [==============================] - 3s 801us/step - loss: 1.3693 - accuracy: 0.5814 - val_loss: 2.1641 - val_accuracy: 0.4362
# Epoch 30/50
# 4171/4171 [==============================] - 4s 873us/step - loss: 1.3549 - accuracy: 0.5814 - val_loss: 2.1185 - val_accuracy: 0.4435
# Epoch 31/50
# 4171/4171 [==============================] - 3s 815us/step - loss: 1.3450 - accuracy: 0.5778 - val_loss: 2.1812 - val_accuracy: 0.4357
# Epoch 32/50
# 4171/4171 [==============================] - 3s 812us/step - loss: 1.3414 - accuracy: 0.5848 - val_loss: 2.1843 - val_accuracy: 0.4385
# Epoch 33/50
# 4171/4171 [==============================] - 4s 868us/step - loss: 1.3088 - accuracy: 0.5883 - val_loss: 2.2890 - val_accuracy: 0.4223
# Epoch 34/50
# 4171/4171 [==============================] - 3s 822us/step - loss: 1.2996 - accuracy: 0.5840 - val_loss: 2.2034 - val_accuracy: 0.4351
# Epoch 35/50
# 4171/4171 [==============================] - 3s 819us/step - loss: 1.2726 - accuracy: 0.5922 - val_loss: 2.2130 - val_accuracy: 0.4441
# Epoch 36/50
# 4171/4171 [==============================] - 4s 840us/step - loss: 1.2474 - accuracy: 0.5898 - val_loss: 2.2745 - val_accuracy: 0.4312
# Epoch 37/50
# 4171/4171 [==============================] - 3s 833us/step - loss: 1.2431 - accuracy: 0.6015 - val_loss: 2.2827 - val_accuracy: 0.4273
# Epoch 38/50
# 4171/4171 [==============================] - 4s 931us/step - loss: 1.2466 - accuracy: 0.5922 - val_loss: 2.2368 - val_accuracy: 0.4323
# Epoch 39/50
# 4171/4171 [==============================] - 4s 864us/step - loss: 1.2113 - accuracy: 0.6018 - val_loss: 2.2886 - val_accuracy: 0.4195
# Epoch 40/50
# 4171/4171 [==============================] - 4s 842us/step - loss: 1.1924 - accuracy: 0.6058 - val_loss: 2.3119 - val_accuracy: 0.4279
# Epoch 41/50
# 4171/4171 [==============================] - 3s 805us/step - loss: 1.1669 - accuracy: 0.6051 - val_loss: 2.2814 - val_accuracy: 0.4273
# Epoch 42/50
# 4171/4171 [==============================] - 3s 804us/step - loss: 1.1702 - accuracy: 0.6035 - val_loss: 2.4190 - val_accuracy: 0.4239
# Epoch 43/50
# 4171/4171 [==============================] - 4s 868us/step - loss: 1.1637 - accuracy: 0.6152 - val_loss: 2.3466 - val_accuracy: 0.4295
# Epoch 44/50
# 4171/4171 [==============================] - 3s 811us/step - loss: 1.1331 - accuracy: 0.6135 - val_loss: 2.3914 - val_accuracy: 0.4228
# Epoch 45/50
# 4171/4171 [==============================] - 3s 811us/step - loss: 1.1345 - accuracy: 0.6145 - val_loss: 2.4399 - val_accuracy: 0.4200
# Epoch 46/50
# 4171/4171 [==============================] - 4s 876us/step - loss: 1.1133 - accuracy: 0.6188 - val_loss: 2.4189 - val_accuracy: 0.4211
# Epoch 47/50
# 4171/4171 [==============================] - 4s 924us/step - loss: 1.1183 - accuracy: 0.6070 - val_loss: 2.4637 - val_accuracy: 0.4239
# Epoch 48/50
# 4171/4171 [==============================] - 3s 815us/step - loss: 1.0846 - accuracy: 0.6250 - val_loss: 2.4106 - val_accuracy: 0.4189
# Epoch 49/50
# 4171/4171 [==============================] - 4s 863us/step - loss: 1.0791 - accuracy: 0.6188 - val_loss: 2.4400 - val_accuracy: 0.4346
# Epoch 50/50
# 4171/4171 [==============================] - 3s 814us/step - loss: 1.0659 - accuracy: 0.6198 - val_loss: 2.5183 - val_accuracy: 0.4262
# Text(0.5, 0, 'accuracy')

# %%
padded_train_title_X.shape
# Out:
# (5959, 20)

# %%
padded_train_text_X.shape
# Out:
# (5959, 551)

# %%
train_y.shape
# Out:
# (5959, 21)
